# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import seaborn as sns

# %%
def chi_sq(x, y, err):
    function = lambda x, a, b: a * x + b
    popt, pcov = curve_fit(function, xdata=x, ydata=y, sigma=err)

    sigma_a = np.sqrt(pcov[0, 0])
    sigma_b = np.sqrt(pcov[1, 1])

    return popt[0], popt[1], sigma_a, sigma_b

# %%
first = pd.read_excel('1.xls')
second = pd.read_excel('2.xls')
third = pd.read_excel('3.xls')
fourth = pd.read_excel('4.xls')
fifth = pd.read_excel('5.xls')
sixth = pd.read_excel('6.xls')
seventh = pd.read_excel('7.xls')
seven_2 = pd.read_excel('7_2.xls')
seven_temp = pd.read_excel('темп_7.xls')

# %%
first
# Out:
#        №          X         Y
# 0      1   0.000000  0.128240
# 1      2   0.083333  0.126442
# 2      3   0.166667  0.125711
# 3      4   0.250000  0.123549
# 4      5   0.333333  0.123182
# ..   ...        ...       ...
# 116  117   9.666667  0.086659
# 117  118   9.750000  0.086165
# 118  119   9.833333  0.086504
# 119  120   9.916667  0.086029
# 120  121  10.000000  0.086546
#
# [121 rows x 3 columns]

# %%
sns.set_theme()

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(first['X'], first['Y'])
plt.xlabel('t, мин')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(second['X'], second['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(third['X'], third['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(fourth['X'], fourth['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(fifth['X'], fifth['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(sixth['X'], sixth['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
concentrations = np.array([-0.0969, 0.176, 0.0792])
peroids = np.array([0.197, 0.054, 0.133])

plt.rcParams["figure.figsize"] = (15,10)
plt.scatter(concentrations, peroids)

a, b, s, e = chi_sq(concentrations,peroids, None)
x = np.linspace(-0.1, 0.2, 100)
y = a * x + b
plt.plot(x,y)

plt.xlabel('lnC')
plt.ylabel('Период колебаний, относительные единицы времени')
# Out:
# Text(0, 0.5, 'Период колебаний, относительные единицы времени')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(seventh['X'], seventh['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(seven_2['X'], seven_2['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot(seven_temp['X'], seven_temp['Y'])
plt.xlabel('Относительное время')
plt.ylabel("Оптическая плотность")
# Out:
# Text(0, 0.5, 'Оптическая плотность')
